# %%
x = [2, 4, 5, 6, 7]
y = [21, 24, 30, 43, 11]
import numpy
import pandas
import matplotlib.pylab as plt
plt.plot(x, y)

# %%
5*2
# Out:
# 10

# %% [markdown]
# Working with unstructured data in Python
